# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Project\\Modular_programming\\ML_modelling\\data\\penguin.csv')
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 334 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            334 non-null    object
#  1   island             334 non-null    object
#  2   culmen_length_mm   334 non-null    float64
#  3   culmen_depth_mm    334 non-null    float64
#  4   flipper_length_mm  334 non-null    float64
#  5   body_mass_g        334 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.9+ KB

# %%
df['species'].value_counts()
# Out:
# Adelie       146
# Gentoo       120
# Chinstrap     68
# Name: species, dtype: int64

# %%
df['island'].value_counts()
# Out:
# Biscoe       164
# Dream        123
# Torgersen     47
# Name: island, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# MALE      168
# FEMALE    165
# .           1
# Name: sex, dtype: int64

# %%
df[df['sex']=='.']
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 336  Gentoo  Biscoe              44.5             15.7              217.0
#
#      body_mass_g sex
# 336       4875.0   .

# %%
 df[df['species']=='Gentoo'].groupby('sex').describe().transpose()
# Out:
# sex                           .       FEMALE         MALE
# culmen_length_mm  count     1.0    58.000000    61.000000
#                   mean     44.5    45.563793    49.473770
#                   std       NaN     2.051247     2.720594
#                   min      44.5    40.900000    44.400000
#                   25%      44.5    43.850000    48.100000
#                   50%      44.5    45.500000    49.500000
#                   75%      44.5    46.875000    50.500000
#                   max      44.5    50.500000    59.600000
# culmen_depth_mm   count     1.0    58.000000    61.000000
#                   mean     15.7    14.237931    15.718033
#                   std       NaN     0.540249     0.741060
#                   min      15.7    13.100000    14.100000
#                   25%      15.7    13.800000    15.200000
#                   50%      15.7    14.250000    15.700000
#                   75%      15.7    14.600000    16.100000
# ...

# %%
df.at[336, 'sex'] = 'FEMALE'

# %%
sns.scatterplot(x = 'culmen_length_mm', y='culmen_depth_mm', data=df, hue='species', palette='Dark2')
# Out:
# <AxesSubplot:xlabel='culmen_length_mm', ylabel='culmen_depth_mm'>

# %%
sns.scatterplot(x = 'culmen_length_mm', y='culmen_depth_mm', data=df, hue='sex', palette='Dark2')
# Out:
# <AxesSubplot:xlabel='culmen_length_mm', ylabel='culmen_depth_mm'>

# %%
sns.scatterplot(x = 'culmen_length_mm', y='culmen_depth_mm', data=df, hue='island', palette='Dark2')
# Out:
# <AxesSubplot:xlabel='culmen_length_mm', ylabel='culmen_depth_mm'>

# %%
sns.pairplot(df, hue='species')

# %%
sns.heatmap(df.corr(), annot = True )
# Out:
# <AxesSubplot:>

# %%
sns.catplot(x='species', y='culmen_length_mm',col = 'sex',  data = df, kind= 'box' )

# %%
x = pd.get_dummies(df.drop('species', axis = 1), drop_first=True)
x
# Out:
#      culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0                39.1             18.7              181.0       3750.0
# 1                39.5             17.4              186.0       3800.0
# 2                40.3             18.0              195.0       3250.0
# 4                36.7             19.3              193.0       3450.0
# 5                39.3             20.6              190.0       3650.0
# ..                ...              ...                ...          ...
# 338              47.2             13.7              214.0       4925.0
# 340              46.8             14.3              215.0       4850.0
# 341              50.4             15.7              222.0       5750.0
# 342              45.2             14.8              212.0       5200.0
# 343              49.9             16.1              213.0       5400.0
#
#      island_Dream  island_Torgersen  sex_MALE
# 0               0                 1         1
# ...

# %%
y = df['species']
y
# Out:
# 0      Adelie
# 1      Adelie
# 2      Adelie
# 4      Adelie
# 5      Adelie
#         ...
# 338    Gentoo
# 340    Gentoo
# 341    Gentoo
# 342    Gentoo
# 343    Gentoo
# Name: species, Length: 334, dtype: object

# %%
sns.violinplot(data= x, x='island_Dream', y='sex_MALE', palette='Dark2')
# Out:
# <AxesSubplot:xlabel='island_Dream', ylabel='sex_MALE'>

# %%
x
# Out:
#      culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0                39.1             18.7              181.0       3750.0
# 1                39.5             17.4              186.0       3800.0
# 2                40.3             18.0              195.0       3250.0
# 4                36.7             19.3              193.0       3450.0
# 5                39.3             20.6              190.0       3650.0
# ..                ...              ...                ...          ...
# 338              47.2             13.7              214.0       4925.0
# 340              46.8             14.3              215.0       4850.0
# 341              50.4             15.7              222.0       5750.0
# 342              45.2             14.8              212.0       5200.0
# 343              49.9             16.1              213.0       5400.0
#
#      island_Dream  island_Torgersen  sex_MALE
# 0               0                 1         1
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state=101)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array(['Chinstrap', 'Gentoo', 'Adelie', 'Chinstrap', 'Gentoo',
#        'Chinstrap', 'Adelie', 'Gentoo', 'Chinstrap', 'Gentoo', 'Adelie',
#        'Adelie', 'Adelie', 'Gentoo', 'Gentoo', 'Adelie', 'Gentoo',
#        'Adelie', 'Adelie', 'Adelie', 'Gentoo', 'Chinstrap', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Chinstrap', 'Gentoo', 'Adelie',
#        'Chinstrap', 'Gentoo', 'Chinstrap', 'Gentoo', 'Adelie', 'Adelie',
#        'Chinstrap', 'Adelie', 'Gentoo', 'Chinstrap', 'Gentoo', 'Adelie',
#        'Adelie', 'Gentoo', 'Adelie', 'Adelie', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Adelie', 'Adelie',
#        'Gentoo', 'Gentoo', 'Adelie', 'Adelie', 'Chinstrap', 'Chinstrap',
#        'Gentoo', 'Adelie', 'Chinstrap', 'Gentoo', 'Adelie', 'Adelie',
#        'Chinstrap', 'Gentoo', 'Chinstrap'], dtype=object)

# %%
from sklearn.metrics import classification_report, plot_confusion_matrix

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.96      0.93      0.95        29
#    Chinstrap       0.90      0.95      0.92        19
#       Gentoo       1.00      1.00      1.00        19
#
#     accuracy                           0.96        67
#    macro avg       0.95      0.96      0.96        67
# weighted avg       0.96      0.96      0.96        67

# %%
plot_confusion_matrix(model, x_test, y_test)
# Out:
# c:\Users\divya\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
model.feature_importances_
# Out:
# array([0.32979464, 0.05488577, 0.58010498, 0.        , 0.03521461,
#        0.        , 0.        ])

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 4  Adelie  Torgersen              36.7             19.3              193.0
# 5  Adelie  Torgersen              39.3             20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 4       3450.0  FEMALE
# 5       3650.0    MALE

# %%
x.columns
# Out:
# Index(['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm',
#        'body_mass_g', 'island_Dream', 'island_Torgersen', 'sex_MALE'],
#       dtype='object')

# %%
pd.DataFrame(index = x.columns, data= model.feature_importances_, columns=['Feature Importance']).sort_values('Feature Importance')
# Out:
#                    Feature Importance
# body_mass_g                  0.000000
# island_Torgersen             0.000000
# sex_MALE                     0.000000
# island_Dream                 0.035215
# culmen_depth_mm              0.054886
# culmen_length_mm             0.329795
# flipper_length_mm            0.580105

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 4  Adelie  Torgersen              36.7             19.3              193.0
# 5  Adelie  Torgersen              39.3             20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 4       3450.0  FEMALE
# 5       3650.0    MALE

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(dpi= 150)
plot_tree(model, filled=True);

# %%
len(x_train)
# Out:
# 267

# %%
plt.figure(dpi= 175)
plot_tree(model, feature_names=x.columns, filled=True);

# %%
 pruned_tree = DecisionTreeClassifier(max_depth=2)

# %%
pruned_tree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
y_pred2 = pruned_tree.predict(x_test)

# %%
def report_model(model):
    print(classification_report(y_test, y_pred2))
    print('\n')
    plt.figure(dpi= 175)
    plot_tree(model, feature_names=x.columns, filled=True);

# %%
report_model(pruned_tree)
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.96      0.93      0.95        29
#    Chinstrap       0.90      0.95      0.92        19
#       Gentoo       1.00      1.00      1.00        19
#
#     accuracy                           0.96        67
#    macro avg       0.95      0.96      0.96        67
# weighted avg       0.96      0.96      0.96        67

# %%
report_model(model)
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.96      0.93      0.95        29
#    Chinstrap       0.90      0.95      0.92        19
#       Gentoo       1.00      1.00      1.00        19
#
#     accuracy                           0.96        67
#    macro avg       0.95      0.96      0.96        67
# weighted avg       0.96      0.96      0.96        67
